# %% [markdown]
# # Processing CLO Mappings
#
#
# The [Cell Line Ontology (CLO)](https://bioregistry.io/registry/clo) is a detailed resouce, however it does not follow standard OBO modeling pattern for cross-references that either uses `oboInOwl:hasDbXref` or a SKOS and pointing to a single CURIE encoded as a string. Instead, it uses `rdfs:seeAlso` with a combination of non-standard CURIEs that are either comma or semi-colon delimited.
#
# This notebook attempts to unpack and operationalize these cross-references.
#
# See also:
#
# - https://github.com/CLO-ontology/CLO/issues/103
# - https://gist.github.com/cthoyt/a91ae12a94c7e1647e9d9d8fa61e80ce

# %%
import pandas as pd
from semra.api import (
    filter_mappings,
    get_many_to_many,
    keep_prefixes,
    summarize_prefixes,
)
from semra.io import get_sssom_df
from semra.sources.clo import get_clo_mappings

from biomappings.resources import (
    PREDICTIONS_HEADER,
    append_prediction_tuples,
    prediction_tuples_from_semra,
)

# %% [markdown]
# ## Extraction and Processing
#
# The following cell uses [this script](https://github.com/biopragmatics/semra/blob/main/src/semra/sources/clo.py) in [SeMRA](https://github.com/biopragmatics/semra) to extract cross-references from CLO.

# %%
mappings = get_clo_mappings()
len(mappings)
# Out:
#   0%|          | 0.00/44.4k [00:00<?, ?node/s]
# CLO:0001584 invalid: atcc:COSMICID:910697 from line:
#   ATCC: COSMIC ID:910697; ATCC CRL-7905,CRL-7905
# CLO:0002336 unparsed: CCL-120 from line:
#   CCL-120
# CLO:0002406 invalid: dsmz:ACC360 from line:
#   DSMZ: ACC 360,COSMIC ID:910568; DSMZ ACC 360
# CLO:0002557 invalid: cldb:Cl847 from line:
#   HyperCLDB: Cl847
# CLO:0002593 unparsed: 92031916 from line:
#   ECACC: 92031916,92031916; COSMIC ID:910555
# CLO:0002899 invalid: dsmz:ACC67 from line:
#   ACC 67
# CLO:0002936 unparsed: 96100920 from line:
#   96100920
# CLO:0003506 invalid: atcc:CRL-2597-Discontinued from line:
#   ATCC: CRL-2597 - Discontinued
# CLO:0003591 invalid: atcc:CRL-8017A from line:
#   ATCC: CRL-8017A
# CLO:0003593 unparsed: :90112119 from line:
#   : 90112119
# CLO:0003627 invalid: dsmz:ACC301 from line:
#   ACC 301
# CLO:0003671 invalid: dsmz:ACC17 from line:
#   ACC 17
# CLO:0003672 invalid: dsmz:ACC346 from line:
#   ACC 346
# CLO:0003682 unparsed: TIB-180 from line:
#   TIB-180
# CLO:0003964 invalid: atcc:CRL-7025-Discontinued from line:
#   ATCC: CRL-7025 - Discontinued
# CLO:0004280 unparsed: ATCCHTB-63 from line:
#   ATCC: HTB-63,COSMIC ID:907067; ATCC HTB-63
# CLO:0007112 invalid: dsmz:ACC8 from line:
#   ACC 8
# CLO:0007189 invalid: dsmz:ACC197 from line:
#   ACC 197
# CLO:0007201 invalid: dsmz:ACC72 from line:
#   ACC 72
# CLO:0007242 invalid: dsmz:ACC673 from line:
#   DSMZ: COSMIC ID:1161992; DSMZ ACC 673,ACC 673
# CLO:0007242 invalid: dsmz:ACC673 from line:
#   DSMZ: COSMIC ID:1161992; DSMZ ACC 673,ACC 673
# CLO:0007330 unparsed: CCL-7.1 from line:
#   ATCC: CCL-7, CCL-7.1
# CLO:0007599 unparsed: HMSL:HMSL50583 from line:
#   CVCL: CVCL_0598; EFO: EFO_0001200; ChEMBL: CHEMBL3307364; HMSL: HMSL50583
# CLO:0007600 unparsed: Cosmic from line:
#   Cosmic; 1136377
# CLO:0007600 unparsed: 1136377 from line:
#   Cosmic; 1136377
# CLO:0007821 invalid: dsmz:ACC437 from line:
#   ACC 437
# CLO:0007938 invalid: dsmz:ACC128 from line:
#   ACC 128
# CLO:0007947 invalid: dsmz:ACC207 from line:
#   ACC 207
# CLO:0008416 invalid: dsmz:ACC6 from line:
#   ACC 6
# CLO:0008512 unparsed: 94060601 from line:
#   ECACC: 94060601,94060601; COSMIC ID:910546
# CLO:0008870 unparsed: CCL-113 from line:
#   CCL-113
# CLO:0009038 unparsed: ATCCHTB-88 from line:
#   ATCC: HTB-88,COSMIC ID:909720; ATCC HTB-88
# CLO:0009042 invalid: atcc:COSMICID:909725 from line:
#   ATCC: COSMIC ID:909725; ATCC HTB-71,HTB-71
# CLO:0009042 unparsed: ATCCHTB-71 from line:
#   ATCC: COSMIC ID:909725; ATCC HTB-71,HTB-71
# CLO:0009042 unparsed: HTB-71 from line:
#   ATCC: COSMIC ID:909725; ATCC HTB-71,HTB-71
# CLO:0009061 invalid: atcc:CRL-8033-1 from line:
#   ATCC: CRL-8033-1
# CLO:0009062 invalid: atcc:CRL-8033-2 from line:
#   ATCC: CRL-8033-2
# CLO:0009421 invalid: atcc:COSMICID:930299 from line:
#   ATCC: COSMIC ID:930299; ATCC CRL-1803,CRL-1803
# CLO:0009456 invalid: jcrb:IFO50288 from line:
#   JHSF: IFO50288
# CLO:0009462 invalid: dsmz:ACC4 from line:
#   ACC 4
# CLO:0009833 unparsed: DFCC-treon: from line:
#   DFCC - treon:
# CLO:0009845 invalid: jcrb:JCRB0105.1 from line:
#   JHSF: JCRB0105.1
# CLO:0009931 invalid: jcrb:JCRB0232.1 from line:
#   JHSF: JCRB0232.1
# CLO:0009947 invalid: jcrb:JCRB0126.1 from line:
#   JHSF: JCRB0126.1
# CLO:0009961 unparsed: 95090714 from line:
#   ECACC: 95090714; COSMIC ID:907292,95090714
# CLO:0009973 unparsed: BWH:621-101 from line:
#   BWH: 621-101,not available
# CLO:0009973 unparsed: notavailable from line:
#   BWH: 621-101,not available
# CLO:0009998 invalid: jcrb:JCRB1080.0 from line:
#   JHSF: JCRB1080.0
# CLO:0037013 unparsed: BroadInstitute:contactprovider from line:
#   Broad Institute: contact provider
# CLO:0037033 unparsed: DFCI:n/a-1 from line:
#   DFCI: n/a-1
# CLO:0037054 invalid: atcc:COSMICID:910401 from line:
#   ATCC: COSMIC ID:910401; ATCC CRL-1923,CRL-1923
# CLO:0037072 unparsed: ATCCHTB-93 from line:
#   ATCC: HTB-93,COSMIC ID:909759; ATCC HTB-93
# CLO:0037079 invalid: jcrb:JCRB:COSMICID:907314 from line:
#   JCRB: COSMIC ID:907314; JCRB IFO50431,IFO50431
# CLO:0037079 invalid: jcrb:JCRBIFO50431 from line:
#   JCRB: COSMIC ID:907314; JCRB IFO50431,IFO50431
# CLO:0037079 unparsed: IFO50431 from line:
#   JCRB: COSMIC ID:907314; JCRB IFO50431,IFO50431
# CLO:0037104 invalid: jcrb:JCRB0234.0 from line:
#   JHSF: JCRB0234.0
# CLO:0037105 invalid: jcrb:JCRB0177.0 from line:
#   JHSF: JCRB0177.0
# CLO:0037106 invalid: jcrb:JCRB0177.1 from line:
#   JHSF: JCRB0177.1
# CLO:0037108 invalid: jcrb:JCRB0178.0 from line:
#   JHSF: JCRB0178.0
# CLO:0037109 invalid: jcrb:JCRB0178.1 from line:
#   JHSF: JCRB0178.1
# CLO:0037112 unparsed: MGH:MGH-1134 from line:
#   MGH: MGH-1134
# CLO:0037131 unparsed: RikenRCB1200 from line:
#   RIKEN: COSMIC ID:925339; Riken RCB1200,RCB1200
# CLO:0037131 unparsed: RCB1200 from line:
#   RIKEN: COSMIC ID:925339; Riken RCB1200,RCB1200
# CLO:0037140 invalid: jcrb:JCRB1075.0 from line:
#   JHSF: JCRB1075.0
# CLO:0037141 invalid: jcrb:JCRB1075.1 from line:
#   JHSF: JCRB1075.1
# CLO:0037166 invalid: atcc:COSMICID:924247 from line:
#   ATCC: COSMIC ID:924247; ATCC HTB-117,HTB-117
# CLO:0037166 unparsed: ATCCHTB-117 from line:
#   ATCC: COSMIC ID:924247; ATCC HTB-117,HTB-117
# CLO:0037166 unparsed: HTB-117 from line:
#   ATCC: COSMIC ID:924247; ATCC HTB-117,HTB-117
# CLO:0037167 invalid: atcc:COSMICID:909758 from line:
#   ATCC: COSMIC ID:909758; ATCC HTB-118,HTB-118
# CLO:0037167 unparsed: ATCCHTB-118 from line:
#   ATCC: COSMIC ID:909758; ATCC HTB-118,HTB-118
# CLO:0037167 unparsed: HTB-118 from line:
#   ATCC: COSMIC ID:909758; ATCC HTB-118,HTB-118
# CLO:0037169 invalid: broad: from line:
#   BROAD:
# CLO:0037170 invalid: jcrb:JCRB:JCRB0163 from line:
#   JCRB: JCRB0163
# CLO:0037171 invalid: jcrb:JCRB:JCRB0006 from line:
#   JCRB: JCRB0006
# CLO:0037174 invalid: jcrb:JCRB:JCRB0147 from line:
#   JCRB: JCRB0147
# CLO:0037177 invalid: jcrb:JCRB:JCRB0123 from line:
#   JCRB: JCRB0123
# CLO:0037183 invalid: jcrb:JCRB:JCRB0146 from line:
#   JCRB: JCRB0146
# CLO:0037184 invalid: cosmic:COSMICID:908149 from line:
#   COSMIC: COSMIC ID:908149
# CLO:0037185 invalid: jcrb:JCRB:JCRB0158.1 from line:
#   JCRB: JCRB0158.1
# CLO:0037186 invalid: jcrb:JCRB:JCRB0158.2 from line:
#   JCRB: JCRB0158.2
# CLO:0037189 unparsed: Asterandbio: from line:
#   Asterandbio:
# CLO:0037271 invalid: bto:BAO_0030063 from line:
#   BTO: BAO_0030063
# CLO:0050067 unparsed: :MGH-889 from line:
#   : MGH-889
# CLO:0050081 invalid: dsmz:ACC6 from line:
#   ACC 6
# CLO:0050117 unparsed: RikenRCB0803 from line:
#   RIKEN: COSMIC ID:925342; Riken RCB0803,RCB0803
# CLO:0050117 unparsed: RCB0803 from line:
#   RIKEN: COSMIC ID:925342; Riken RCB0803,RCB0803
# CLO:0050475 invalid: jcrb:JCRB0158.0 from line:
#   JCRB0158.0
# CLO:0050793 unparsed: RikenRCB0555 from line:
#   RIKEN: COSMIC ID:906869; Riken RCB0555,RCB0555
# CLO:0050793 unparsed: RCB0555 from line:
#   RIKEN: COSMIC ID:906869; Riken RCB0555,RCB0555
# CLO:0050796 unparsed: RikenRCB0983 from line:
#   RIKEN: COSMIC ID:906848; Riken RCB0983,RCB0983
# CLO:0050796 unparsed: RCB0983 from line:
#   RIKEN: COSMIC ID:906848; Riken RCB0983,RCB0983
# CLO:0050801 unparsed: RIKEN:RCB1148 from line:
#   RIKEN: RCB1148,COSMIC ID:909770; Riken RCB1148
# CLO:0050801 unparsed: RikenRCB1148 from line:
#   RIKEN: RCB1148,COSMIC ID:909770; Riken RCB1148
# CLO:0050970 invalid: dsmz:ACC128 from line:
#   ACC 128
# CLO:0051539 unparsed: RikenRCB0478 from line:
#   RIKEN: COSMIC ID:910929; Riken RCB0478,RCB0478
# CLO:0051539 unparsed: RCB0478 from line:
#   RIKEN: COSMIC ID:910929; Riken RCB0478,RCB0478
# 10925

# %% [markdown]
# ## Prefix Summary
#
# The table below this cell summarizes all of the prefixes appearing in cross-references extracted from CLO.

# %%
summarize_prefixes(mappings)
# Out:
#                                                                name  \
# prefix
# atcc                               American Type Culture Collection
# bao                                               BioAssay Ontology
# biosample                                                 BioSample
# bto                                          BRENDA Tissue Ontology
# cellosaurus                                             Cellosaurus
# chembl.cell       ChEMBL database of bioactive drug-like small m...
# cldb                                             Cell Line Database
# clo                                              Cell Line Ontology
# cosmic.cell                                       COSMIC Cell Lines
# dsmz              Deutsche Sammlung von Mikroorganismen und Zell...
# ebisc              European Bank for induced pluripotent Stem Cells
# ecacc             European Collection of Authenticated Cell Culture
# efo                                    Experimental Factor Ontology
# hms.lincs.cell                                       HMS LINCS Cell
# iclc                                  Interlab Cell Line Collection
# jcrb                                                 JRBC Cell Bank
# mesh                                       Medical Subject Headings
# obi                          Ontology for Biomedical Investigations
# pubchem.bioassay          NCBI PubChem database of bioassay records
# reo                                                Reagent Ontology
# thermofisher                               Thermo Fisher Scientific
#
#                                                         description
# prefix
# atcc              The American Type Culture Collection (ATCC) is...
# bao               The BioAssay Ontology (BAO) describes chemical...
# biosample         The BioSample Database stores information abou...
# bto               The Brenda tissue ontology is a structured con...
# cellosaurus       The Cellosaurus is a knowledge resource on cel...
# chembl.cell                                     Chemistry resources
# cldb              The Cell Line Data Base (CLDB) is a reference ...
# clo               The Cell Line Ontology is a community-based on...
# cosmic.cell       COSMIC, the Catalogue Of Somatic Mutations In ...
# dsmz              The Leibniz Institute DSMZ is the most diverse...
# ebisc                                         Cell line collections
# ecacc             The European Collection of Authenticated Cell ...
# efo               The Experimental Factor Ontology (EFO) provide...
# hms.lincs.cell    Database contains all publicly available HMS L...
# iclc                                          Cell line collections
# jcrb                                          Cell line collections
# mesh              MeSH (Medical Subject Headings) is the Nationa...
# obi               The Ontology for Biomedical Investigations (OB...
# pubchem.bioassay  PubChem provides information on the biological...
# reo               The Reagent Ontology (ReO) adheres to OBO Foun...
# thermofisher         ThermoFisher is a life sciences supply vendor.

# %% [markdown]
# Many of the resources cross-referenced by CLO aren't accessible in a structured format. Therefore, we can't programatically look up names or synonyms. In some (but not all) cases, the resource has a site that can be used to manually examine information about a given record, but this ultimately leaves review very difficult.
#
# There might be an automated way to get the list of all resources that can be used with `pyobo.get_name`, but until that's figured out, the following is a shortlist of resources we can follow up on easily.

# %%
DESIRED_PREFIXES = {"bto", "efo", "mesh", "cellosaurus", "obi", "clo"}

mappings = keep_prefixes(mappings, prefixes=DESIRED_PREFIXES, progress=False)
len(mappings)
# Out:
# 812

# %% [markdown]
# ## Identify Inconsistencies
#
# The following cell identifies many-to-many mappings, e.g., when a given CLO has multiple cross-references to entities in another semantic space, or visa-versa.

# %%
m2m_mappings = get_many_to_many(mappings)
get_sssom_df(m2m_mappings, add_labels=True)
# Out:
# Preparing SSSOM:   0%|          | 0.00/25.0 [00:00<?, ?mapping/s]
#      subject_id         subject_label        predicate_id         object_id  \
# 0   clo:0001230                HEK293  oboInOwl:hasDbXref  cellosaurus:0045
# 1   clo:0037237      293-derived cell  oboInOwl:hasDbXref  cellosaurus:0045
# 2   clo:0007050            K 562 cell  oboInOwl:hasDbXref  cellosaurus:0004
# 3   clo:0007059            K-562 cell  oboInOwl:hasDbXref  cellosaurus:0004
# 4   clo:0037163         Ishikawa cell  oboInOwl:hasDbXref  cellosaurus:D199
# 5   clo:0037230  Ishikawa 3-H-12 cell  oboInOwl:hasDbXref  cellosaurus:D199
# 6   clo:0037300           BALL-1 cell  oboInOwl:hasDbXref  cellosaurus:1075
# 7   clo:0051004          RCB0256 cell  oboInOwl:hasDbXref  cellosaurus:1075
# 8   clo:0051005          RCB1882 cell  oboInOwl:hasDbXref  cellosaurus:1075
# 9   clo:0037372          HEK293T cell  oboInOwl:hasDbXref  cellosaurus:0063
# 10  clo:0050894          RCB2202 cell  oboInOwl:hasDbXref  cellosaurus:0063
# 11  clo:0050405          RCB2280 cell  oboInOwl:hasDbXref  cellosaurus:1272
# 12  clo:0050406          RCB1384 cell  oboInOwl:hasDbXref  cellosaurus:1272
# 13  clo:0002585          COR-L23 cell  oboInOwl:hasDbXref       efo:0002142
# 14  clo:0037287           COR123 cell  oboInOwl:hasDbXref       efo:0002142
# 15  clo:0007634       MDA-MB-231 cell  oboInOwl:hasDbXref       efo:0001209
# 16  clo:0037291         MDAMB231 cell  oboInOwl:hasDbXref       efo:0001209
# 17  clo:0009034          SK-BR-3 cell  oboInOwl:hasDbXref       efo:0001236
# 18  clo:0037295            SKBR3 cell  oboInOwl:hasDbXref       efo:0001236
# 19  clo:0009040         SK-MEL-1 cell  oboInOwl:hasDbXref       efo:0002332
# 20  clo:0037292                SKMEL1  oboInOwl:hasDbXref       efo:0002332
# 21  clo:0001345              3T3 cell  oboInOwl:hasDbXref      mesh:D016475
# 22  clo:0037261      3T3-derived cell  oboInOwl:hasDbXref      mesh:D016475
# 23  clo:0002596            COS-1 cell  oboInOwl:hasDbXref      mesh:D019556
# 24  clo:0002597            COS-7 cell  oboInOwl:hasDbXref      mesh:D019556
#
#        object_label       mapping_justification mapping_set  \
# 0            HEK293  semapv:UnspecifiedMatching         clo
# 1            HEK293  semapv:UnspecifiedMatching         clo
# 2             K-562  semapv:UnspecifiedMatching         clo
# 3             K-562  semapv:UnspecifiedMatching         clo
# 4   Ishikawa 3-H-12  semapv:UnspecifiedMatching         clo
# 5   Ishikawa 3-H-12  semapv:UnspecifiedMatching         clo
# 6            BALL-1  semapv:UnspecifiedMatching         clo
# 7            BALL-1  semapv:UnspecifiedMatching         clo
# 8            BALL-1  semapv:UnspecifiedMatching         clo
# 9           HEK293T  semapv:UnspecifiedMatching         clo
# 10          HEK293T  semapv:UnspecifiedMatching         clo
# 11            HCE-T  semapv:UnspecifiedMatching         clo
# 12            HCE-T  semapv:UnspecifiedMatching         clo
# 13           CORL23  semapv:UnspecifiedMatching         clo
# 14           CORL23  semapv:UnspecifiedMatching         clo
# 15         MDAMB231  semapv:UnspecifiedMatching         clo
# 16         MDAMB231  semapv:UnspecifiedMatching         clo
# 17            SKBR3  semapv:UnspecifiedMatching         clo
# 18            SKBR3  semapv:UnspecifiedMatching         clo
# 19           SKMEL1  semapv:UnspecifiedMatching         clo
# 20           SKMEL1  semapv:UnspecifiedMatching         clo
# 21        3T3 Cells  semapv:UnspecifiedMatching         clo
# 22        3T3 Cells  semapv:UnspecifiedMatching         clo
# 23        COS Cells  semapv:UnspecifiedMatching         clo
# 24        COS Cells  semapv:UnspecifiedMatching         clo
#
#    mapping_set_version mapping_set_license  mapping_set_confidence
# 0              2.1.178           CC-BY-3.0                     0.8
# 1              2.1.178           CC-BY-3.0                     0.8
# 2              2.1.178           CC-BY-3.0                     0.8
# 3              2.1.178           CC-BY-3.0                     0.8
# 4              2.1.178           CC-BY-3.0                     0.8
# 5              2.1.178           CC-BY-3.0                     0.8
# 6              2.1.178           CC-BY-3.0                     0.8
# 7              2.1.178           CC-BY-3.0                     0.8
# 8              2.1.178           CC-BY-3.0                     0.8
# 9              2.1.178           CC-BY-3.0                     0.8
# 10             2.1.178           CC-BY-3.0                     0.8
# 11             2.1.178           CC-BY-3.0                     0.8
# 12             2.1.178           CC-BY-3.0                     0.8
# 13             2.1.178           CC-BY-3.0                     0.8
# 14             2.1.178           CC-BY-3.0                     0.8
# 15             2.1.178           CC-BY-3.0                     0.8
# 16             2.1.178           CC-BY-3.0                     0.8
# 17             2.1.178           CC-BY-3.0                     0.8
# 18             2.1.178           CC-BY-3.0                     0.8
# 19             2.1.178           CC-BY-3.0                     0.8
# 20             2.1.178           CC-BY-3.0                     0.8
# 21             2.1.178           CC-BY-3.0                     0.8
# 22             2.1.178           CC-BY-3.0                     0.8
# 23             2.1.178           CC-BY-3.0                     0.8
# 24             2.1.178           CC-BY-3.0                     0.8

# %% [markdown]
# Add short set of xrefs that aren't exact for triage

# %%
append_prediction_tuples(
    prediction_tuples_from_semra(m2m_mappings, confidence=0.8), standardize=True
)
# Out:
# Standardizing mappings: 0.00mapping [00:00, ?mapping/s]
# Removing curated from predicted:   0%|          | 0.00/40.5k [00:00<?, ?it/s]

# %% [markdown]
# Check out the remainder

# %%
rows = prediction_tuples_from_semra(
    filter_mappings(mappings, m2m_mappings, progress=False), confidence=0.8
)
pd.DataFrame(rows, columns=PREDICTIONS_HEADER)
# Out:
# can not look up name for efo:0002082
# can not look up name for efo:0002823
# can not look up name for efo:0002080
# can not look up name for efo:0002336
# can not look up name for efo:0001256
# can not look up name for efo:0002387
#     source prefix source identifier      source name         relation  \
# 0             clo           0001008         697 cell  skos:exactMatch
# 1             clo           0001088        143B cell  skos:exactMatch
# 2             clo           0001230           HEK293  skos:exactMatch
# 3             clo           0001230           HEK293  skos:exactMatch
# 4             clo           0001234  293/CHE-Fc cell  skos:exactMatch
# ..            ...               ...              ...              ...
# 776           clo           0051547     RCB2084 cell  skos:exactMatch
# 777           clo           0051567     RCB1902 cell  skos:exactMatch
# 778           clo           0051568     RCB1974 cell  skos:exactMatch
# 779           clo           0051569     RCB1975 cell  skos:exactMatch
# 780           clo           0051609     RCB0881 cell  skos:exactMatch
#
#     target prefix target identifier                 target name  \
# 0     cellosaurus              0079                         697
# 1     cellosaurus              2270                        143B
# 2             bto           0000007                HEK-293 cell
# 3             efo           0001182                      HEK293
# 4     cellosaurus              6352                  293/CHE-Fc
# ..            ...               ...                         ...
# 776   cellosaurus              1736  TALL-1 [Human adult T-ALL]
# 777   cellosaurus              1289                       HSC-4
# 778   cellosaurus              1675                         SAS
# 779   cellosaurus              1288                       HSC-3
# 780   cellosaurus              1621                      OCUB-M
#
#                            type  confidence source
# 0    semapv:UnspecifiedMatching         0.8    clo
# 1    semapv:UnspecifiedMatching         0.8    clo
# 2    semapv:UnspecifiedMatching         0.8    clo
# 3    semapv:UnspecifiedMatching         0.8    clo
# 4    semapv:UnspecifiedMatching         0.8    clo
# ..                          ...         ...    ...
# 776  semapv:UnspecifiedMatching         0.8    clo
# 777  semapv:UnspecifiedMatching         0.8    clo
# 778  semapv:UnspecifiedMatching         0.8    clo
# 779  semapv:UnspecifiedMatching         0.8    clo
# 780  semapv:UnspecifiedMatching         0.8    clo
#
# [781 rows x 10 columns]
